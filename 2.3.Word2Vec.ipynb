# %%
from __future__ import division, print_function, absolute_import

import collections
import os
import random
# no urllib in python 3
#import urllib
import urllib.request
import zipfile

import numpy as np
import tensorflow as tf

# %%
# Training Parameters.
learning_rate = 0.1
batch_size = 128
num_steps = 3000000
display_step = 10000
eval_step = 200000

# Evaluation Parameters.
# eval_words = ['five', 'of', 'going', 'hardware', 'american', 'britain']
# change to byte for python3 
eval_words = [b'five', b'of', b'going', b'hardware', b'american', b'britain']

# Word2Vec Parameters.
embedding_size = 200 # Dimension of the embedding vector.
max_vocabulary_size = 50000 # Total number of different words in the vocabulary.
min_occurrence = 10 # Remove all words that does not appears at least n times.
skip_window = 3 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
num_sampled = 64 # Number of negative examples to sample.

# %%
# Download a small chunk of Wikipedia articles collection.
url = 'http://mattmahoney.net/dc/text8.zip'
data_path = 'text8.zip'
if not os.path.exists(data_path):
    print("Downloading the dataset... (It may take some time)")
    # filename, _ = urllib.urlretrieve(url, data_path)
    filename, _ =urllib.request.urlretrieve(url, data_path)
    print("Done!")
# Unzip the dataset file. Text has already been processed.
with zipfile.ZipFile(data_path) as f:
    text_words = f.read(f.namelist()[0]).lower().split()

# %%
# Build the dictionary and replace rare words with UNK token.
count = [('UNK', -1)]
# Retrieve the most common words.
count.extend(collections.Counter(text_words).most_common(max_vocabulary_size - 1))
# Remove samples with less than 'min_occurrence' occurrences.
for i in range(len(count) - 1, -1, -1):
    if count[i][1] < min_occurrence:
        count.pop(i)
    else:
        # The collection is ordered, so stop when 'min_occurrence' is reached.
        break
# Compute the vocabulary size.
vocabulary_size = len(count)
# Assign an id to each word.
word2id = dict()
for i, (word, _)in enumerate(count):
    word2id[word] = i

data = list()
unk_count = 0
for word in text_words:
    # Retrieve a word id, or assign it index 0 ('UNK') if not in dictionary.
    index = word2id.get(word, 0)
    if index == 0:
        unk_count += 1
    data.append(index)
count[0] = ('UNK', unk_count)
id2word = dict(zip(word2id.values(), word2id.keys()))

print("Words count:", len(text_words))
print("Unique words:", len(set(text_words)))
print("Vocabulary size:", vocabulary_size)
print("Most common words:", count[:10])
# Out:
# Words count: 17005207
# Unique words: 253854
# Vocabulary size: 47135
# Most common words: [('UNK', 444176), (b'the', 1061396), (b'of', 593677), (b'and', 416629), (b'one', 411764), (b'in', 372201), (b'a', 325873), (b'to', 316376), (b'zero', 264975), (b'nine', 250430)]

# %%
data_index = 0
# Generate training batch for the skip-gram model.
def next_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # get window size (words left and right + current one).
    span = 2 * skip_window + 1
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer.extend(data[0:span])
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch.
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
# Ensure the following ops & var are assigned on CPU
# (some ops are not compatible on GPU).
with tf.device('/cpu:0'):
    # Create the embedding variable (each row represent a word embedding vector).
    embedding = tf.Variable(tf.random.normal([vocabulary_size, embedding_size]))
    # Construct the variables for the NCE loss.
    nce_weights = tf.Variable(tf.random.normal([vocabulary_size, embedding_size]))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

def get_embedding(x):
    with tf.device('/cpu:0'):
        # Lookup the corresponding embedding vectors for each sample in X.
        x_embed = tf.nn.embedding_lookup(embedding, x)
        return x_embed

def nce_loss(x_embed, y):
    with tf.device('/cpu:0'):
        # Compute the average NCE loss for the batch.
        y = tf.cast(y, tf.int64)
        loss = tf.reduce_mean(
            tf.nn.nce_loss(weights=nce_weights,
                           biases=nce_biases,
                           labels=y,
                           inputs=x_embed,
                           num_sampled=num_sampled,
                           num_classes=vocabulary_size))
        return loss

# Evaluation.
def evaluate(x_embed):
    with tf.device('/cpu:0'):
        # Compute the cosine similarity between input data embedding and every embedding vectors
        x_embed = tf.cast(x_embed, tf.float32)
        x_embed_norm = x_embed / tf.sqrt(tf.reduce_sum(tf.square(x_embed)))
        embedding_norm = embedding / tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keepdims=True), tf.float32)
        cosine_sim_op = tf.matmul(x_embed_norm, embedding_norm, transpose_b=True)
        return cosine_sim_op

# Define the optimizer.
optimizer = tf.optimizers.SGD(learning_rate)

# %%
# Optimization process. 
def run_optimization(x, y):
    with tf.device('/cpu:0'):
        # Wrap computation inside a GradientTape for automatic differentiation.
        with tf.GradientTape() as g:
            emb = get_embedding(x)
            loss = nce_loss(emb, y)

        # Compute gradients.
        gradients = g.gradient(loss, [embedding, nce_weights, nce_biases])

        # Update W and b following gradients.
        optimizer.apply_gradients(zip(gradients, [embedding, nce_weights, nce_biases]))

# %%
# Words for testing.
x_test = np.array([word2id[w] for w in eval_words])

# Run training for the given number of steps.
# no xrange in python 3
for step in range(1, num_steps + 1):

    batch_x, batch_y = next_batch(batch_size, num_skips, skip_window)
    run_optimization(batch_x, batch_y)
    
    if step % display_step == 0 or step == 1:
        loss = nce_loss(get_embedding(batch_x), batch_y)
        print("step: %i, loss: %f" % (step, loss))
        
    # Evaluation.
    if step % eval_step == 0 or step == 1:
        print("Evaluation...")
        sim = evaluate(get_embedding(x_test)).numpy()
        for i in range(len(eval_words)):
            top_k = 8  # number of nearest neighbors.
            nearest = (-sim[i, :]).argsort()[1:top_k + 1]
            log_str = '"%s" nearest neighbors:' % eval_words[i]
            for k in range(top_k):
                log_str = '%s %s,' % (log_str, id2word[nearest[k]])
            print(log_str)
# Out:
# step: 1, loss: 498.519470
# Evaluation...
# "b'five'" nearest neighbors: b'coordination', b'sher', b'mel', b'damian', b'samael', b'relevant', b'somers', b'uriah',
# "b'of'" nearest neighbors: b'heralded', b'suing', b'galois', b'rambouillet', b'tackling', b'martingale', b'balder', b'midyear',
# "b'going'" nearest neighbors: b'drill', b'junction', b'plume', b'draco', b'fellowships', b'sawdust', b'maude', b'hydrofoils',
# "b'hardware'" nearest neighbors: b'willis', b'primes', b'sanctus', b'pathologies', b'tightened', b'ncaa', b'tablet', b'djs',
# "b'american'" nearest neighbors: b'disabled', b'britanniae', b'toxic', b'circled', b'loom', b'snoop', b'governor', b'chewing',
# "b'britain'" nearest neighbors: b'djs', b'deride', b'umar', b'yusuf', b'avian', b'cappella', b'aspartame', b'leuven',
# step: 10000, loss: 140.881866
# step: 20000, loss: 75.009331
# step: 30000, loss: 50.946983
# step: 40000, loss: 21.223032
# step: 50000, loss: 40.325272
# step: 60000, loss: 44.388191
# step: 70000, loss: 19.011478
# step: 80000, loss: 30.268120
# step: 90000, loss: 47.921776
# step: 100000, loss: 36.555027
# step: 110000, loss: 24.035286
# step: 120000, loss: 14.842275
# step: 130000, loss: 32.486202
# step: 140000, loss: 21.569323
# step: 150000, loss: 9.971032
# step: 160000, loss: 21.763315
# step: 170000, loss: 13.687380
# step: 180000, loss: 19.463737
# step: 190000, loss: 8.818431
# step: 200000, loss: 17.137789
# Evaluation...
# "b'five'" nearest neighbors: b'three', b'four', b'six', b'two', b'seven', b'eight', b'nine', b'zero',
# "b'of'" nearest neighbors: b'the', b'by', b'on', b'a', b'in', b'and', b'was', b'first',
# "b'going'" nearest neighbors: b'general', b'two', b'five', b'seven', b'from', b'during', b's', b'called',
# "b'hardware'" nearest neighbors: b'peter', b'andrew', b'branch', b'august', b'notes', b'referred', b'zero', b'january',
# "b'american'" nearest neighbors: UNK, b'and', b'in', b'about', b'from', b'between', b's', b'with',
# "b'britain'" nearest neighbors: b'in', b'time', b'and', b'or', b'there', b'which', b'by', b'who',
# step: 210000, loss: 12.021742
# step: 220000, loss: 13.830315
# step: 230000, loss: 20.217196
# step: 240000, loss: 6.660910
# step: 250000, loss: 8.760660
# step: 260000, loss: 13.974520
# step: 270000, loss: 8.746334
# step: 280000, loss: 7.070324
# step: 290000, loss: 10.146935
# step: 300000, loss: 9.642256
# step: 310000, loss: 14.499058
# step: 320000, loss: 10.105896
# step: 330000, loss: 10.788838
# step: 340000, loss: 10.034904
# step: 350000, loss: 14.647251
# step: 360000, loss: 7.793616
# step: 370000, loss: 7.937390
# step: 380000, loss: 7.285100
# step: 390000, loss: 8.371565
# step: 400000, loss: 7.705888
# Evaluation...
# "b'five'" nearest neighbors: b'four', b'six', b'three', b'seven', b'eight', b'two', b'one', b'zero',
# "b'of'" nearest neighbors: b'the', b'for', b'its', b'and', b'a', b'also', b'by', b'with',
# "b'going'" nearest neighbors: b'film', UNK, b'and', b'such', b'or', b'called', b's', b'based',
# "b'hardware'" nearest neighbors: UNK, b'de', b'only', b'are', b'first', b'some', b'an', b'used',
# "b'american'" nearest neighbors: b's', b'in', b'british', b'after', b'over', b'including', b'and', b'about',
# "b'britain'" nearest neighbors: b'being', b'used', b'about', b'where', b'long', b'r', b'from', b'people',
# step: 410000, loss: 6.429708
# step: 420000, loss: 22.291618
# step: 430000, loss: 9.730312
# step: 440000, loss: 6.711824
# step: 450000, loss: 6.054163
# step: 460000, loss: 11.495188
# step: 470000, loss: 5.151491
# step: 480000, loss: 12.831387
# step: 490000, loss: 6.515735
# step: 500000, loss: 12.725754
# step: 510000, loss: 9.448769
# step: 520000, loss: 8.081374
# step: 530000, loss: 8.049997
# step: 540000, loss: 6.803340
# step: 550000, loss: 14.920202
# step: 560000, loss: 7.299780
# step: 570000, loss: 6.556117
# step: 580000, loss: 7.069123
# step: 590000, loss: 7.457480
# step: 600000, loss: 6.042125
# Evaluation...
# "b'five'" nearest neighbors: b'three', b'four', b'six', b'two', b'seven', b'eight', b'one', b'zero',
# "b'of'" nearest neighbors: b'and', b'the', b'including', b'which', b'where', b'its', b'while', b'for',
# "b'going'" nearest neighbors: b'another', b'film', b'part', b'up', b'the', b'from', b'at', b'after',
# "b'hardware'" nearest neighbors: UNK, b'and', b'based', b'order', b'some', b'non', b'de', b'example',
# "b'american'" nearest neighbors: b'english', b'french', b'german', b'british', b's', b'in', b'from', b'including',
# "b'britain'" nearest neighbors: b'and', b'about', b'between', b'all', b'only', b'in', b'r', b'by',
# step: 610000, loss: 3.565796
# step: 620000, loss: 5.216366
# step: 630000, loss: 6.674751
# step: 640000, loss: 9.778908
# step: 650000, loss: 8.035447
# step: 660000, loss: 7.549051
# step: 670000, loss: 5.937440
# step: 680000, loss: 4.563313
# step: 690000, loss: 6.994250
# step: 700000, loss: 7.087436
# step: 710000, loss: 12.137506
# step: 720000, loss: 5.262304
# step: 730000, loss: 8.078056
# step: 740000, loss: 7.136170
# step: 750000, loss: 10.929585
# step: 760000, loss: 8.646247
# step: 770000, loss: 11.573254
# step: 780000, loss: 7.635587
# step: 790000, loss: 9.459738
# step: 800000, loss: 6.566732
# Evaluation...
# "b'five'" nearest neighbors: b'three', b'four', b'six', b'seven', b'two', b'eight', b'one', b'nine',
# "b'of'" nearest neighbors: b'and', b'in', b'including', b'the', b'by', b'from', b'for', b'while',
# "b'going'" nearest neighbors: b'named', b'back', b'air', b'game', b'man', b'or', b'example', b'another',
# "b'hardware'" nearest neighbors: b'also', b'other', b'free', b'some', b'order', b'by', b'was', b'him',
# "b'american'" nearest neighbors: b'english', b'b', b'born', b'british', b'french', b'd', b'german', b'john',
# "b'britain'" nearest neighbors: b'major', b'about', b'society', b'life', b'second', b'to', b'where', b'old',
# step: 810000, loss: 6.562624
# step: 820000, loss: 5.724887
# step: 830000, loss: 6.719349
# step: 840000, loss: 5.507804
# step: 850000, loss: 7.674723
# step: 860000, loss: 5.733249
# step: 870000, loss: 5.623880
# step: 880000, loss: 7.263638
# step: 890000, loss: 6.264339
# step: 900000, loss: 6.104330
# step: 910000, loss: 6.218675
# step: 920000, loss: 8.116293
# step: 930000, loss: 7.867630
# step: 940000, loss: 6.552627
# step: 950000, loss: 8.317184
# step: 960000, loss: 6.474846
# step: 970000, loss: 7.286081
# step: 980000, loss: 5.041792
# step: 990000, loss: 6.503771
# step: 1000000, loss: 5.280115
# Evaluation...
# "b'five'" nearest neighbors: b'four', b'three', b'six', b'eight', b'seven', b'two', b'nine', b'zero',
# "b'of'" nearest neighbors: b'the', b'first', b'including', b'following', b'and', b'second', b'from', b'its',
# "b'going'" nearest neighbors: b'named', b'air', b'back', b'life', b'a', b'based', b'another', b'word',
# "b'hardware'" nearest neighbors: b'example', b'some', b'although', b'also', b'an', b'free', b'god', b'is',
# "b'american'" nearest neighbors: b'd', b'b', b'born', UNK, b'nine', b'french', b'john', b'one',
# "b'britain'" nearest neighbors: b'major', b'where', b'second', b'life', b'society', b'several', b'named', b'each',
# step: 1010000, loss: 5.690192
# step: 1020000, loss: 5.578153
# step: 1030000, loss: 11.765482
# step: 1040000, loss: 5.863242
# step: 1050000, loss: 8.597800
# step: 1060000, loss: 5.377607
# step: 1070000, loss: 6.766290
# step: 1080000, loss: 6.612053
# step: 1090000, loss: 5.365820
# step: 1100000, loss: 5.098700
# step: 1110000, loss: 6.896734
# step: 1120000, loss: 6.718119
# step: 1130000, loss: 6.250028
# step: 1140000, loss: 5.639534
# step: 1150000, loss: 5.589215
# step: 1160000, loss: 5.716095
# step: 1170000, loss: 9.000023
# step: 1180000, loss: 6.882421
# step: 1190000, loss: 7.392263
# step: 1200000, loss: 6.259706
# Evaluation...
# "b'five'" nearest neighbors: b'three', b'four', b'six', b'seven', b'eight', b'two', b'nine', b'zero',
# "b'of'" nearest neighbors: b'the', b'and', b'in', b'following', b'from', b'including', b'by', b'with',
# "b'going'" nearest neighbors: b'back', b'based', b'same', b'even', b'named', b'another', b'because', b'air',
# "b'hardware'" nearest neighbors: b'free', b'also', b'non', b'many', b'some', b'different', b'although', b'data',
# "b'american'" nearest neighbors: b'born', b'd', b'german', b'b', b'john', b'british', UNK, b's',
# "b'britain'" nearest neighbors: b'society', b'second', b'following', b'between', b'major', b'old', b'about', b'before',
# step: 1210000, loss: 6.279122
# step: 1220000, loss: 5.932155
# step: 1230000, loss: 6.203350
# step: 1240000, loss: 6.400753
# step: 1250000, loss: 7.233575
# step: 1260000, loss: 7.435946
# step: 1270000, loss: 7.026515
# step: 1280000, loss: 8.979749
# step: 1290000, loss: 5.880692
# step: 1300000, loss: 6.705301
# step: 1310000, loss: 5.366918
# step: 1320000, loss: 5.660424
# step: 1330000, loss: 5.416622
# step: 1340000, loss: 5.602193
# step: 1350000, loss: 5.841493
# step: 1360000, loss: 7.363449
# step: 1370000, loss: 5.141858
# step: 1380000, loss: 5.388556
# step: 1390000, loss: 5.476816
# step: 1400000, loss: 7.556121
# Evaluation...
# "b'five'" nearest neighbors: b'four', b'six', b'three', b'eight', b'seven', b'two', b'one', b'zero',
# "b'of'" nearest neighbors: b'the', b'and', b'modern', b'its', b'for', b'in', b'including', b'all',
# "b'going'" nearest neighbors: b'back', b'same', b'based', b'next', b'due', b'show', b'air', b'a',
# "b'hardware'" nearest neighbors: b'non', b'free', b'other', b'although', b'research', b'written', b'all', b'data',
# "b'american'" nearest neighbors: b'english', b'french', b'german', b'british', b'born', b'film', b'former', b'john',
# "b'britain'" nearest neighbors: b'between', b'second', b'people', b'by', b'from', b'life', b'society', b'power',
# step: 1410000, loss: 7.924754
# step: 1420000, loss: 4.532741
# step: 1430000, loss: 5.456903
# step: 1440000, loss: 6.553022
# step: 1450000, loss: 5.149653
# step: 1460000, loss: 6.515644
# step: 1470000, loss: 6.789418
# step: 1480000, loss: 6.765896
# step: 1490000, loss: 5.477674
# step: 1500000, loss: 5.310760
# step: 1510000, loss: 6.947688
# step: 1520000, loss: 6.142008
# step: 1530000, loss: 5.376127
# step: 1540000, loss: 7.305986
# step: 1550000, loss: 6.187057
# step: 1560000, loss: 4.798240
# step: 1570000, loss: 5.450606
# step: 1580000, loss: 4.908823
# step: 1590000, loss: 7.134905
# step: 1600000, loss: 5.566981
# Evaluation...
# "b'five'" nearest neighbors: b'four', b'six', b'three', b'eight', b'two', b'seven', b'one', b'zero',
# "b'of'" nearest neighbors: b'and', b'the', b'including', b'in', b'from', b'following', b'modern', b'with',
# "b'going'" nearest neighbors: b'back', b'next', b'same', b'another', b'up', b'for', b'from', b'where',
# "b'hardware'" nearest neighbors: b'free', b'non', b'data', b'research', b'some', b'although', b'other', b'or',
# "b'american'" nearest neighbors: b'born', b'british', b'english', b'french', b'b', b'german', b'd', b'john',
# "b'britain'" nearest neighbors: b'between', b'great', b'following', b'second', b'old', b'society', b'through', b'and',
# step: 1610000, loss: 5.475514
# step: 1620000, loss: 5.072116
# step: 1630000, loss: 6.985889
# step: 1640000, loss: 5.004600
# step: 1650000, loss: 7.129155
# step: 1660000, loss: 7.447233
# step: 1670000, loss: 5.260544
# step: 1680000, loss: 5.552962
# step: 1690000, loss: 5.516575
# step: 1700000, loss: 7.495758
# step: 1710000, loss: 5.762661
# step: 1720000, loss: 5.878797
# step: 1730000, loss: 5.753469
# step: 1740000, loss: 6.176472
# step: 1750000, loss: 5.912714
# step: 1760000, loss: 11.325809
# step: 1770000, loss: 5.038842
# step: 1780000, loss: 5.320018
# step: 1790000, loss: 4.714517
# step: 1800000, loss: 7.865271
# Evaluation...
# "b'five'" nearest neighbors: b'four', b'three', b'six', b'seven', b'eight', b'two', b'nine', b'zero',
# "b'of'" nearest neighbors: b'the', b'first', b'following', b'and', b'in', b'society', b'became', b'second',
# "b'going'" nearest neighbors: b'back', b'next', b'through', b'because', b'same', b'time', b'take', b'even',
# "b'hardware'" nearest neighbors: b'data', b'research', b'non', b'free', b'current', b'computer', b'software', b'also',
# "b'american'" nearest neighbors: b'b', b'd', b'born', b'actor', UNK, b'robert', b'english', b'nine',
# "b'britain'" nearest neighbors: b'germany', b'england', b'second', b'between', b'great', b'france', b'from', b'in',
# step: 1810000, loss: 6.190084
# step: 1820000, loss: 6.585926
# step: 1830000, loss: 6.724565
# step: 1840000, loss: 5.554301
# step: 1850000, loss: 5.708755
# step: 1860000, loss: 6.624519
# step: 1870000, loss: 5.399193
# step: 1880000, loss: 5.327434
# step: 1890000, loss: 5.519406
# step: 1900000, loss: 5.095676
# step: 1910000, loss: 5.351163
# step: 1920000, loss: 5.220162
# step: 1930000, loss: 7.126097
# step: 1940000, loss: 4.855742
# step: 1950000, loss: 5.233091
# step: 1960000, loss: 6.587995
# step: 1970000, loss: 5.169248
# step: 1980000, loss: 5.547123
# step: 1990000, loss: 7.356876
# step: 2000000, loss: 6.418758
# Evaluation...
# "b'five'" nearest neighbors: b'four', b'three', b'six', b'seven', b'eight', b'two', b'nine', b'zero',
# "b'of'" nearest neighbors: b'the', b'modern', b'and', b'including', b'its', b'following', b'in', b'first',
# "b'going'" nearest neighbors: b'back', b'next', b'time', b'same', b'through', b'came', b'even', b'just',
# "b'hardware'" nearest neighbors: b'free', b'data', b'computer', b'non', b'research', b'design', b'software', b'program',
# "b'american'" nearest neighbors: b'actor', b'd', b'born', b'b', b'robert', b'german', b'john', b'british',
# "b'britain'" nearest neighbors: b'england', b'great', b'northern', b'germany', b'europe', b'france', b'second', b'from',
# step: 2010000, loss: 5.063718
# step: 2020000, loss: 5.273862
# step: 2030000, loss: 5.153220
# step: 2040000, loss: 6.366675
# step: 2050000, loss: 5.576917
# step: 2060000, loss: 3.909154
# step: 2070000, loss: 4.935148
# step: 2080000, loss: 4.624276
# step: 2090000, loss: 4.655439
# step: 2100000, loss: 6.460117
# step: 2110000, loss: 6.151036
# step: 2120000, loss: 7.228026
# step: 2130000, loss: 5.920149
# step: 2140000, loss: 7.415414
# step: 2150000, loss: 6.018028
# step: 2160000, loss: 4.965418
# step: 2170000, loss: 5.233773
# step: 2180000, loss: 5.665016
# step: 2190000, loss: 5.250909
# step: 2200000, loss: 6.031650
# Evaluation...
# "b'five'" nearest neighbors: b'four', b'three', b'six', b'seven', b'eight', b'two', b'zero', b'one',
# "b'of'" nearest neighbors: b'and', b'modern', b'the', b'from', b'in', b'include', b'for', b'on',
# "b'going'" nearest neighbors: b'back', b'time', b'because', b'next', b'came', b'close', b'making', b'once',
# "b'hardware'" nearest neighbors: b'computer', b'data', b'free', b'software', b'design', b'research', b'program', b'systems',
# "b'american'" nearest neighbors: b'canadian', b'german', b'english', b'french', b'british', b'italian', b'born', b'russian',
# "b'britain'" nearest neighbors: b'england', b'germany', b'great', b'northern', b'europe', b'france', b'second', b'throughout',
# step: 2210000, loss: 4.342942
# step: 2220000, loss: 6.036028
# step: 2230000, loss: 5.220033
# step: 2240000, loss: 7.349520
# step: 2250000, loss: 5.399380
# step: 2260000, loss: 5.189495
# step: 2270000, loss: 8.387444
# step: 2280000, loss: 5.708110
# step: 2290000, loss: 5.627777
# step: 2300000, loss: 5.137299
# step: 2310000, loss: 6.362388
# step: 2320000, loss: 5.335626
# step: 2330000, loss: 5.778580
# step: 2340000, loss: 5.789030
# step: 2350000, loss: 6.277373
# step: 2360000, loss: 5.231965
# step: 2370000, loss: 6.206852
# step: 2380000, loss: 5.551373
# step: 2390000, loss: 5.279981
# step: 2400000, loss: 6.623813
# Evaluation...
# "b'five'" nearest neighbors: b'four', b'three', b'six', b'seven', b'two', b'eight', b'nine', b'zero',
# "b'of'" nearest neighbors: b'the', b'in', b'following', b'from', b'and', b'including', b'modern', b'original',
# "b'going'" nearest neighbors: b'back', b'close', b'next', b'through', b'because', b'another', b'take', b'actually',
# "b'hardware'" nearest neighbors: b'free', b'data', b'computer', b'systems', b'design', b'program', b'software', b'personal',
# "b'american'" nearest neighbors: b'actor', b'canadian', b'born', b'english', b'british', b'b', b'd', b'french',
# "b'britain'" nearest neighbors: b'england', b'northern', b'france', b'germany', b'europe', b'great', b'government', b'following',
# step: 2410000, loss: 5.007449
# step: 2420000, loss: 5.494690
# step: 2430000, loss: 5.206448
# step: 2440000, loss: 6.074399
# step: 2450000, loss: 5.146227
# step: 2460000, loss: 4.503060
# step: 2470000, loss: 6.275219
# step: 2480000, loss: 5.753365
# step: 2490000, loss: 5.302571
# step: 2500000, loss: 5.263486
# step: 2510000, loss: 5.438573
# step: 2520000, loss: 5.604191
# step: 2530000, loss: 7.119954
# step: 2540000, loss: 5.223993
# step: 2550000, loss: 4.891226
# step: 2560000, loss: 5.223510
# step: 2570000, loss: 5.960316
# step: 2580000, loss: 5.561504
# step: 2590000, loss: 6.555329
# step: 2600000, loss: 5.549012
# Evaluation...
# "b'five'" nearest neighbors: b'four', b'three', b'six', b'seven', b'eight', b'nine', b'two', b'one',
# "b'of'" nearest neighbors: b'the', b'and', b'became', b'following', b'society', b'first', b'famous', b'including',
# "b'going'" nearest neighbors: b'close', b'back', b'another', b'through', b'take', b'up', b'actually', b'way',
# "b'hardware'" nearest neighbors: b'data', b'free', b'systems', b'software', b'computer', b'information', b'program', b'non',
# "b'american'" nearest neighbors: b'actor', b'b', b'singer', b'd', b'author', b'born', b'robert', b'writer',
# "b'britain'" nearest neighbors: b'england', b'france', b'germany', b'northern', b'europe', b'great', b'under', b'from',
# step: 2610000, loss: 7.404179
# step: 2620000, loss: 5.465616
# step: 2630000, loss: 5.106429
# step: 2640000, loss: 5.116678
# step: 2650000, loss: 5.339254
# step: 2660000, loss: 7.203570
# step: 2670000, loss: 6.412424
# step: 2680000, loss: 5.521646
# step: 2690000, loss: 6.112698
# step: 2700000, loss: 5.437140
# step: 2710000, loss: 5.514125
# step: 2720000, loss: 5.893735
# step: 2730000, loss: 6.012786
# step: 2740000, loss: 5.967257
# step: 2750000, loss: 5.245255
# step: 2760000, loss: 6.469204
# step: 2770000, loss: 5.709495
# step: 2780000, loss: 5.676019
# step: 2790000, loss: 5.057936
# step: 2800000, loss: 4.952061
# Evaluation...
# "b'five'" nearest neighbors: b'six', b'four', b'three', b'eight', b'seven', b'two', b'nine', b'one',
# "b'of'" nearest neighbors: b'in', b'the', b'and', b'from', b'following', b'including', b'part', b'its',
# "b'going'" nearest neighbors: b'close', b'back', b'went', b'time', b'started', b'designed', b'next', b'once',
# "b'hardware'" nearest neighbors: b'free', b'design', b'systems', b'software', b'computer', b'data', b'programs', b'program',
# "b'american'" nearest neighbors: b'actor', b'singer', b'author', b'd', b'writer', b'canadian', b'born', b'b',
# "b'britain'" nearest neighbors: b'england', b'france', b'germany', b'great', b'northern', b'europe', b'established', b'western',
# step: 2810000, loss: 5.646502
# step: 2820000, loss: 6.526423
# step: 2830000, loss: 6.451826
# step: 2840000, loss: 7.659240
# step: 2850000, loss: 5.419694
# step: 2860000, loss: 5.192353
# step: 2870000, loss: 5.483469
# step: 2880000, loss: 5.631757
# step: 2890000, loss: 5.390798
# step: 2900000, loss: 4.795035
# step: 2910000, loss: 4.947577
# step: 2920000, loss: 5.923408
# step: 2930000, loss: 4.795883
# step: 2940000, loss: 6.860466
# step: 2950000, loss: 4.764144
# step: 2960000, loss: 5.895561
# step: 2970000, loss: 5.775353
# step: 2980000, loss: 5.959985
# step: 2990000, loss: 5.384745
# step: 3000000, loss: 5.738762
# Evaluation...
# "b'five'" nearest neighbors: b'three', b'six', b'four', b'seven', b'eight', b'two', b'zero', b'nine',
# "b'of'" nearest neighbors: b'the', b'and', b'including', b'in', b'modern', b'includes', b'for', b'original',
# "b'going'" nearest neighbors: b'close', b'back', b'went', b'once', b'take', b'made', b'put', b'without',
# "b'hardware'" nearest neighbors: b'computer', b'software', b'design', b'free', b'programs', b'data', b'systems', b'information',
# "b'american'" nearest neighbors: b'canadian', b'british', b'english', b'irish', b'author', b'french', b'german', b'italian',
# "b'britain'" nearest neighbors: b'england', b'france', b'great', b'germany', b'northern', b'europe', b'established', b'western',

# %%
dict(list(word2id.items())[:3])
# Out:
# {'UNK': 0, b'the': 1, b'of': 2}

# %%
word2id[b'the']
# Out:
# 1
